# %% [markdown]
# <a href="https://colab.research.google.com/github/jhdavis04/cs_notes/blob/main/scopes_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Coding Exercise: Understanding Variable Scope
#
# This lab explores how variable scope works in programming. You will investigate local vs global variables, shadowing, block scope, and lifetime. You may answer using Python code cells or write C++ code externally if you prefer.
#
# **Estimated time: 40 minutes**

# %% [markdown]
# ## Part 1 — Predict the Output
#
# Read the code below carefully before running it. Write down what you think the output will be and explain why. Focus on how the variable `x` behaves inside and outside the function.

# %%
x = 10

def foo():
    x = 5
    print('Inside foo:', x)

foo()
print('Outside:', x)

# %% [markdown]
# **Questions:**
# - What line of code did each printing?
# - Why does changing `x` inside the function not affect the global variable?
# - How would you modify the function to change the global value?

# %% [markdown]
# ## Part 2 — Fix the Bug
#
# The following program is intended to increment a global counter, but it contains a scope bug. Modify the code so that the counter updates correctly.

# %%
counter = 0

def increment():
    counter = counter + 1

increment()
print(counter)

# %% [markdown]
# **Task:**
# - Fix the program so it prints `1`.
# - Explain what caused the bug.
# - Describe why scope rules matter here.

# %% [markdown]
# ## Part 3 — Shadowing Challenge
#
# This example demonstrates variable shadowing. Run the code and explain the output. Pay attention to how Python treats variables inside conditional blocks.

# %%
value = 100

def test():
    value = 50
    if True:
        value = 25
    print(value)

test()
print(value)

# %% [markdown]
# **Questions:**
# - How can shadowing lead to bugs?

# %% [markdown]
# ## Part 4 — Design Task
#
# Write a function that keeps track of how many times it has been called. Each call should return the next number in sequence (1, 2, 3, …).
#
# You may use:
# - A global variable
# - Any correct approach
#
# After implementing, explain which scope mechanism you used.

# %%
# Write your solution here

# %% [markdown]
# ## Reflection Questions
#
# - When should global variables be avoided?
# - Why can shadowing make debugging harder?
# - How does understanding scope help prevent bugs or security issues?
# - Compare Python and C++ scope rules.
